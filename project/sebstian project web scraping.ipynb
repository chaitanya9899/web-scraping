# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import bs4
from urllib.request import urlopen
from bs4 import BeautifulSoup

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import xlrd
import lxml

Country = []
Mariane_Name = []
state = []
Slips = []
Moorings = []
list_rows1 = []
list_rows2 = []
list_rows3 = []
list_rows4 = []
list_rows5 = []
list_rows6 = []
list_rows7 = []
list_rows8 = []
list_rows9 = []
list_rows10 = []
list_rows11 = []
list_rows12 = []
list_rows13 = []
list_rows14 = []
list_rows15 = []
list_rows16 = []
list_rows17= []
list_rows18 = []
list_rows19= []
list_rows20= []
list_rows21= []
list_rows22= []
list_rows23= []
list_rows24= []
list_rows25 = []
list_rows26 = []
list_rows27 = []
list_rows28 = []
list_rows29 = []
list_rows30 = []
list_rows31 = []
list_rows32 = []
list_rows33 = []
list_rows34 = []
list_rows35 = []
list_rows36 = []
list_rows37 = []
list_rows38 = []
list_rows39 = []
list_rows40 = []
list_rows41 = []
list_rows42 = []
list_rows43 = []
list_rows43 = []
list_rows44 = []

def scraping():
    loc = (r"D:\book1.xlsx")
    wb = xlrd.open_workbook(loc)
    sheet = wb.sheet_by_index(0)
    sheet.cell_value(0, 0)
    driver = webdriver.Chrome(r'D:\chromedriver_win32\\chromedriver')
    for i in range(sheet.nrows):
        # print(sheet.cell_value(i, 0))
        strproductID = sheet.cell_value(i, 0)
        # print(strproductID)
        if (strproductID != " "):
            driver.get(strproductID)
            for i in range(0,24):
                page_source = driver.page_source
                #print(page_source)
                soup2 = BeautifulSoup(page_source, 'html.parser')
            #print(soup2)
                type(soup2)

                bs4.BeautifulSoup

                title = soup2.title
                #print(title)


                try:
                    python_button = driver.find_elements_by_xpath("//img[@class='hide-img-on-error card-img-top']")[i]
                    python_button.click()
                    strong_tag = soup2.find_all("a", {"class": "breadcrumb-item"})
                    Country.append(strong_tag[2].text)

                except:
                    #python_button = driver.find_elements_by_xpath("//img[@class='hide-img-on-error']")[0]
                    #python_button.click()
                    break

                page_source = driver.page_source
                # print(page_source)
                soup = BeautifulSoup(page_source, 'lxml')
                # print(soup)
                type(soup)

                bs4.BeautifulSoup



                strong_tag = soup.find("h1", {"class": "text-center text-sm-left text-weight-600"})
                try:
                    Mariane_Name.append(strong_tag.text)
                except:
                    Mariane_Name.append("NAN")
                citystatestrong_tag = soup.find_all("li", {"class": "breadcrumb-item"})

                # State
                try:
                    state.append(citystatestrong_tag[1].text)
                except:
                    state.append("NAN")

                # berthCapacity
                berthCapacity_tag = soup.find_all("div", {"class": "col-sm-6 mb-3"})
                try:
                    Slips.append(berthCapacity_tag[0].text)
                except:
                    Slips.append("NAN")
                try:
                    Moorings.append(berthCapacity_tag[1].text)
                except:
                    Moorings.append("NAN")

                # Services & Amenities
                amenities_tag = soup.find_all("div", {"class": "col-sm-6 mb-3"})
                try:
                    list_rows1.append(amenities_tag[2].text)
                except:
                    list_rows1.append("NAN")
                try:
                    list_rows2.append(amenities_tag[3].text)
                except:
                    list_rows2.append("NAN")
                try:
                    list_rows3.append(amenities_tag[4].text)
                except:
                    list_rows3.append("NAN")
                try:
                    list_rows4.append(amenities_tag[5].text)
                except:
                    list_rows4.append("NAN")
                try:
                    list_rows5.append(amenities_tag[6].text)
                except:
                    list_rows5.append("NAN")
                try:
                    list_rows6.append(amenities_tag[7].text)
                except:
                    list_rows6.append("NAN")
                try:
                    list_rows7.append(amenities_tag[8].text)
                except:
                    list_rows7.append("NAN")
                try:
                    list_rows8.append(amenities_tag[9].text)
                except:
                    list_rows8.append("NAN")
                try:
                    list_rows9.append(amenities_tag[10].text)
                except:
                    list_rows9.append("NAN")
                try:
                    list_rows10.append(amenities_tag[11].text)
                except:
                    list_rows10.append("NAN")

                try:
                    list_rows11.append(amenities_tag[12].text)
                except:
                    list_rows11.append("NAN")
                try:
                    list_rows12.append(amenities_tag[13].text)
                except:
                    list_rows12.append("NAN")
                try:
                    list_rows13.append(amenities_tag[14].text)
                except:
                    list_rows13.append("NAN")
                try:
                    list_rows14.append(amenities_tag[15].text)
                except:
                    list_rows14.append("NAN")
                try:
                    list_rows15.append(amenities_tag[16].text)
                except:
                    list_rows15.append("NAN")
                try:
                    list_rows16.append(amenities_tag[17].text)
                except:
                    list_rows16.append("NAN")
                try:
                    list_rows17.append(amenities_tag[18].text)
                except:
                    list_rows17.append("NAN")
                try:
                    list_rows18.append(amenities_tag[19].text)
                except:
                    list_rows18.append("NAN")
                try:
                    list_rows19.append(amenities_tag[20].text)
                except:
                    list_rows19.append("NAN")
                try:
                    list_rows20.append(amenities_tag[21].text)
                except:
                    list_rows20.append("NAN")
                try:
                    list_rows21.append(amenities_tag[22].text)
                except:
                    list_rows21.append("NAN")
                try:
                    list_rows22.append(amenities_tag[23].text)
                except:
                    list_rows22.append("NAN")
                try:
                    list_rows23.append(amenities_tag[24].text)
                except:
                    list_rows23.append("NAN")
                try:
                    list_rows24.append(amenities_tag[25].text)
                except:
                    list_rows24.append("NAN")
                try:
                    list_rows25.append(amenities_tag[26].text)
                except:
                    list_rows25.append("NAN")
                try:
                    list_rows26.append(amenities_tag[27].text)
                except:
                    list_rows26.append("NAN")
                try:
                    list_rows27.append(amenities_tag[28].text)
                except:
                    list_rows27.append("NAN")
                try:
                    list_rows28.append(amenities_tag[29].text)
                except:
                    list_rows28.append("NAN")
                try:
                    list_rows29.append(amenities_tag[30].text)
                except:
                    list_rows29.append("NAN")
                try:
                    list_rows30.append(amenities_tag[31].text)
                except:
                    list_rows30.append("NAN")
                try:
                    list_rows31.append(amenities_tag[32].text)
                except:
                    list_rows31.append("NAN")
                try:
                    list_rows32.append(amenities_tag[33].text)
                except:
                    list_rows32.append("NAN")
                try:
                    list_rows33.append(amenities_tag[34].text)
                except:
                    list_rows33.append("NAN")
                try:
                    list_rows34.append(amenities_tag[35].text)
                except:
                    list_rows34.append("NAN")
                try:
                    list_rows35.append(amenities_tag[36].text)
                except:
                    list_rows35.append("NAN")
                try:
                    list_rows36.append(amenities_tag[37].text)
                except:
                    list_rows36.append("NAN")
                try:
                    list_rows37.append(amenities_tag[38].text)
                except:
                    list_rows37.append("NAN")
                try:
                    list_rows38.append(amenities_tag[39].text)
                except:
                    list_rows38.append("NAN")
                try:
                    list_rows39.append(amenities_tag[40].text)
                except:
                    list_rows39.append("NAN")
                try:
                    list_rows40.append(amenities_tag[41].text)
                except:
                    list_rows40.append("NAN")
                try:
                    list_rows41.append(amenities_tag[42].text)
                except:
                    list_rows41.append("NAN")
                try:
                    list_rows42.append(amenities_tag[43].text)
                except:
                    list_rows42.append("NAN")
                try:
                    list_rows43.append(amenities_tag[44].text)
                except:
                    list_rows43.append("NAN")
                try:
                    list_rows44.append(amenities_tag[45].text)
                except:
                    list_rows44.append("NAN")

                driver.get(strproductID)

scraping()
df = pd.DataFrame(data={"Mariane Name:":Mariane_Name,"Country":Country,"State":state ,"slips":Slips,"Mornings":Moorings,"row1":list_rows1,"row2":list_rows2,"row3":list_rows3,"row4":list_rows4,"row5":list_rows5,"row6":list_rows6,"row7":list_rows7,"row8":list_rows8,"row9":list_rows9,"row10":list_rows10,"row11":list_rows11,"row12":list_rows12,"row13":list_rows13,"row14":list_rows14,"row15":list_rows15,"row16":list_rows16,"row17":list_rows17,"row18":list_rows18,"row19":list_rows19,"row20":list_rows20,"row21":list_rows21,"row22":list_rows22,"row23":list_rows23,"row24":list_rows24,"row25":list_rows25,"row26":list_rows26,"row27":list_rows27,"row28":list_rows28,"row29":list_rows29,"row30":list_rows30,"row31":list_rows31,"row32":list_rows32,"row33":list_rows33,"row34":list_rows34,"row35":list_rows35,"row36":list_rows36,"row37":list_rows37,"row38":list_rows38,"row39":list_rows39,"row40":list_rows40,"row41":list_rows41,"row42":list_rows42,"row43":list_rows43,"row44":list_rows44})
df.to_csv(r"D:\marinas\qubek1.csv",  sep=',',index=False)
df.head(100)
# Out:
#                              Mariane Name:        Country          State  \
# 0                                      NAN  United States            NAN
# 1                    Dauphin Island Marina  United States        Alabama
# 2                         Dog River Marina  United States        Alabama
# 3                         Fly Creek Marina  United States        Alabama
# 4                      Fairhope Yacht Club  United States        Alabama
# 5                     Grand Mariner Marina  United States        Alabama
# 6                     Pirate's Marina Cove  United States        Alabama
# 7                   Florence Harbor Marina  United States        Alabama
# 8                       Beachcomber Marina  United States        Alabama
# 9                        Bear Point Harbor  United States        Alabama
# 10                      Master Marine Inc.  United States        Alabama
# 11                     Orange Beach Marina  United States        Alabama
# ...
